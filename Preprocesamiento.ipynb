# %%
#Mostrar cuantoas imagenes hay en cada categoria
# %pip install matplotlib
#python -m venv tf_env
#source tf_env/bin/activate
# %pip install --upgrade pip
#%pip install tensorflow[and-cuda]
# %pip install tensorflow
# %pip install scipy
# %pip install tensorflow_hub

# !ls ../Monografia/SetDePruevaNP/a | wc -l
# !ls ../Monografia/SetDePruevaNP/b | wc -l
# !ls ../Monografia/SetDePruevaNP/c | wc -l
# !ls ../Monografia/SetDePruevaNP/d | wc -l
# !ls ../Monografia/SetDePruevaNP/e | wc -l
# !ls ../Monografia/SetDePruevaNP/f | wc -l
# !ls ../Monografia/SetDePruevaNP/i | wc -l
# !ls ../Monografia/SetDePruevaNP/k | wc -l
# !ls ../Monografia/SetDePruevaNP/l | wc -l
# !ls ../Monografia/SetDePruevaNP/m | wc -l
# !ls ../Monografia/SetDePruevaNP/n | wc -l
# !ls ../Monografia/SetDePruevaNP/o | wc -l
# !ls ../Monografia/SetDePruevaNP/p | wc -l
# !ls ../Monografia/SetDePruevaNP/q | wc -l
# !ls ../Monografia/SetDePruevaNP/r | wc -l
# !ls ../Monografia/SetDePruevaNP/t | wc -l
# !ls ../Monografia/SetDePruevaNP/u | wc -l
# !ls ../Monografia/SetDePruevaNP/v | wc -l
# !ls ../Monografia/SetDePruevaNP/w | wc -l
# !ls ../Monografia/SetDePruevaNP/y | wc -l
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# 10
# 9
# 10
# 8
# 12
# 10
# 12
# 11
# 10
# 8
# 8
# 10
# 6
# 10
# 11
# 10
# 12
# 10
# 12
# 11

# %%
#
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '../Monografia/SetDePruevaNP/a'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
# !mkdir ../Monografia/SetDePruevaPreprocesado

# !mkdir ../Monografia/SetDePruevaPreprocesado/a
# !mkdir ../Monografia/SetDePruevaPreprocesado/b
# !mkdir ../Monografia/SetDePruevaPreprocesado/c
# !mkdir ../Monografia/SetDePruevaPreprocesado/d
# !mkdir ../Monografia/SetDePruevaPreprocesado/e
# !mkdir ../Monografia/SetDePruevaPreprocesado/f
# !mkdir ../Monografia/SetDePruevaPreprocesado/i
# !mkdir ../Monografia/SetDePruevaPreprocesado/k
# !mkdir ../Monografia/SetDePruevaPreprocesado/l
# !mkdir ../Monografia/SetDePruevaPreprocesado/m
# !mkdir ../Monografia/SetDePruevaPreprocesado/n
# !mkdir ../Monografia/SetDePruevaPreprocesado/o
# !mkdir ../Monografia/SetDePruevaPreprocesado/p
# !mkdir ../Monografia/SetDePruevaPreprocesado/q
# !mkdir ../Monografia/SetDePruevaPreprocesado/r
# !mkdir ../Monografia/SetDePruevaPreprocesado/t
# !mkdir ../Monografia/SetDePruevaPreprocesado/u
# !mkdir ../Monografia/SetDePruevaPreprocesado/v
# !mkdir ../Monografia/SetDePruevaPreprocesado/w
# !mkdir ../Monografia/SetDePruevaPreprocesado/y
# Out:
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/a»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/b»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/c»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/d»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/e»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/f»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/i»: El fichero ya existe
# mkdir: no se puede crear el directorio «../Monografia/SetDePruevaPreprocesado/k»: El fichero ya existe
# ...

# %%
import shutil
carpeta_fuente = '../Monografia/SetDePruevaNP/a'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/a'

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/b'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/b'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimgb in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimgb, carpeta_destino + '/' + nombreimgb)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/c'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/c'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/d'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/d'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/e'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/e'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/f'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/f'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/i'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/i'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/k'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/k'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/l'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/l'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/m'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/m'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/n'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/n'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/o'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/o'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/p'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/p'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/q'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/q'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/r'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/r'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/t'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/t'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/u'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/u'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/w'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/w'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '../Monografia/SetDePruevaNP/y'
carpeta_destino = '../Monografia/SetDePruevaPreprocesado/y'
imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
)

#Generadores para sets de entrenamiento y pruebas
data_gen_entrenamiento = datagen.flow_from_directory('../Monografia/SetDeEntrenamiento/', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('../Monografia/SetDePruevaPreprocesado/', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# 2026-01-13 20:25:48.604049: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-13 20:27:41.141717: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /home/konnorjpc/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Found 4000 images belonging to 20 classes.
# Found 0 images belonging to 20 classes.

# %%
#%pip uninstall -y keras
#%pip show tensorflow tensorflow_hub

import tensorflow as tf
import tensorflow_hub as hub


url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))
# Out:
# 2026-01-13 20:28:34.215577: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
#Congelar el modelo descargado
mobilenetv2.trainable = False

# %%
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(20, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 modelo = tf.keras.Sequential([
#       2     mobilenetv2,
#       3     tf.keras.layers.Dense(20, activation='softmax')
#       4 ])
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/models/sequential.py:75, in Sequential.__init__(self, layers, trainable, name)
#      73 if layers:
#      74     for layer in layers:
# ---> 75         self.add(layer, rebuild=False)
#      76     self._maybe_rebuild()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/models/sequential.py:97, in Sequential.add(self, layer, rebuild)
#      95         layer = origin_layer
#      96 if not isinstance(layer, Layer):
# ---> 97     raise ValueError(
#      98         "Only instances of `keras.Layer` can be "
#      99         f"added to a Sequential model. Received: {layer} "
# ...

# %%
modelo.summary()
